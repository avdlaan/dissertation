# %% [markdown]
# <a href="https://colab.research.google.com/github/avdlaan/dissertation/blob/main/Kaggle_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
! cd /root/
! ls -lrta /root/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# total 12
# drwx------ 1 root root 4096 Nov  6 21:05 ..
# drwxr-xr-x 2 root root 4096 Nov  6 21:05 .

# %%
! cp /content/drive/MyDrive/kaggle.json /root/.kaggle/kaggle.json
! chmod 600 /root/.kaggle/kaggle.json

# %%
! kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
# Out:
# ...
# 100% 12.1G/12.1G [04:36<00:00, 39.2MB/s]
# 100% 12.1G/12.1G [04:36<00:00, 47.0MB/s]

# %%
! cd /content/drive/MyDrive

# %%
# !mkdir /content/drive/MyDrive/train

# %%
# !unzip /content/CORD-19-research-challenge.zip -d /content/drive/MyDrive/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593855.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593858.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593865.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593929.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593933.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593941.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593952.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593954.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7593974.xml.json
#   inflating: /content/drive/MyDrive/train/document_parses/pmc_json/PMC7594018.xml.json
# ...
